# %%
PrimeiroValor = int(input('Digite o 1 valor:'))
SegundoValor = int(input('Digite o 2 valor:'))
TerceiroValor = int(input('Digite o 3 valor:'))

if PrimeiroValor > SegundoValor and PrimeiroValor > TerceiroValor:
  print('o maior numero e', PrimeiroValor)
elif SegundoValor > PrimeiroValor and SegundoValor > TerceiroValor:
  print('o maior numero e', SegundoValor)
elif TerceiroValor > PrimeiroValor and TerceiroValor > SegundoValor:
    print('o maior numero e', TerceiroValor)

if PrimeiroValor < SegundoValor and PrimeiroValor < TerceiroValor:
  print('o menor numero e', PrimeiroValor)
elif SegundoValor < PrimeiroValor and SegundoValor < TerceiroValor:
  print('o menor numero e', SegundoValor)
elif TerceiroValor < PrimeiroValor and TerceiroValor < SegundoValor:
    print('o menor numero e', TerceiroValor)
# Out:
# Digite o 1 valor:10
# Digite o 2 valor:20
# Digite o 3 valor:30
# o maior numero e 30
# o menor numero e 10
